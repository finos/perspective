# %%
import ujson
import lantern as l
from perspective import psp
# Out:
# Matplotlib loaded
# Cufflinks loaded
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="af17beee-53b4-445c-9764-9865ecf2d99e">Loading BokehJS ...</span>
#     </div>
# Plot.ly loaded
# Qgrid loaded
# Perspective loaded

# %%
df = l.bar.sample()

# %%
data = df.to_json(orient='records')

# %%
psp(data, 'xy_scatter')
